# %%
import numpy as np
import pandas as pd 
import keras
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
# Out:
# Using TensorFlow backend.

# %%
# assign FAST_RUN=True to train the model with three epochs
FAST_RUN = False

# input image dimensions
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)

# red, green and blue channels
IMAGE_CHANNELS=3

# %%
dataframe = pd.read_csv("../input/siim-isic-melanoma-classification/train.csv")
dataframe.columns
# Out:
# Index(['image_name', 'patient_id', 'sex', 'age_approx',
#        'anatom_site_general_challenge', 'diagnosis', 'benign_malignant',
#        'target'],
#       dtype='object')

# %%
dataframe=dataframe.drop(labels=["patient_id","sex","age_approx","anatom_site_general_challenge","diagnosis","benign_malignant"],axis=1)
dataframe["image_name"]=dataframe["image_name"].apply(lambda x:x+".jpg")
dataframe.shape
# Out:
# (33126, 2)

# %%
benign_df=dataframe[dataframe.target==0].copy()
malignant_df = dataframe[dataframe.target==1].copy()

# %%
benign_df.head(3)
# Out:
#          image_name  target
# 0  ISIC_2637011.jpg       0
# 1  ISIC_0015719.jpg       0
# 2  ISIC_0052212.jpg       0

# %%
malignant_df.head(3)
# Out:
#            image_name  target
# 91   ISIC_0149568.jpg       1
# 235  ISIC_0188432.jpg       1
# 314  ISIC_0207268.jpg       1

# %%
train_benign,val_benign = train_test_split(benign_df,test_size=0.2,random_state=0)
train_malignant, val_malignant = train_test_split(malignant_df,test_size=0.2,random_state=0)
print(train_benign.shape[0])
print(val_benign.shape[0])
print(train_malignant.shape[0])
print(val_malignant.shape[0])
# Out:
# 26033
# 6509
# 467
# 117

# %%
train_malignant_oversampled = train_malignant.copy()

while(True):
    if train_malignant_oversampled.shape[0] > train_benign.shape[0]:
        break
    train_malignant_oversampled = pd.concat([train_malignant_oversampled,train_malignant])
    
print(train_benign.shape[0])
print(val_benign.shape[0])
print(train_malignant_oversampled.shape[0])
print(val_malignant.shape[0])
# Out:
# 26033
# 6509
# 26152
# 117

# %%
train_df = pd.concat([train_benign,train_malignant_oversampled])
val_df = pd.concat([val_benign,val_malignant])
print(train_df.shape)
print(val_df.shape)
# Out:
# (52185, 2)
# (6626, 2)

# %%
train_df['target'].value_counts().plot.bar()

# %%
# random.choice(train_df["image_name"].values)

# %%
sample = random.choice(train_df["image_name"].values)
image = load_img("../input/siim-isic-melanoma-classification/jpeg/train/"+sample)
plt.imshow(image)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

# layer 1
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#layer 2
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#layer 3
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#fully connected layer
model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 61, 61, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
# !mkdir saved_model
# Out:
# mkdir: cannot create directory ‘saved_model’: File exists

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
import os

class CustomSaver(keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        if(os.path.isfile('saved_model/history.csv')!=True):
            history_df=pd.DataFrame(columns = ['loss','val_loss','accuracy','val_accuracy']) 
            history_df.to_csv('saved_model/history.csv',index=False)
        self.history_df = pd.read_csv('saved_model/history.csv')
        
    def on_epoch_end(self, epoch, logs={}):
        print("Epoch:",epoch)
        print("Loss:",logs["loss"],"Val_loss:",logs["val_loss"],"Accuracy:",logs["accuracy"],"Val_accuracy:",logs["val_accuracy"])
        self.model.save_weights("saved_model/model_"+str(self.history_df.shape[0])+".h5")
        print("Saved weights: "+"saved_model/model_"+str(self.history_df.shape[0])+".h5")
        self.history_df=self.history_df.append({'loss':logs["loss"],
                   'val_loss':logs['val_loss'],
                   'accuracy':logs['accuracy'],
                   'val_accuracy':logs['val_accuracy']},ignore_index = True)
        self.history_df.to_csv('saved_model/history.csv',index=False)
         
saver = CustomSaver()

# %%
callbacks = [earlystop, learning_rate_reduction,saver]

# %%
train_df["target"] = train_df["target"].replace({0: 'benign', 1: 'malignant'}) 
val_df["target"] = val_df["target"].replace({0: 'benign', 1: 'malignant'})

# %%
train_df.head(5)
# Out:
#              image_name  target
# 19144  ISIC_5809628.jpg  benign
# 11364  ISIC_3500137.jpg  benign
# 8017   ISIC_2497305.jpg  benign
# 4969   ISIC_1592874.jpg  benign
# 3291   ISIC_1092935.jpg  benign

# %%
train_df = train_df.reset_index(drop=True)
validate_df = val_df.reset_index(drop=True)

# %%
train_df['target'].value_counts().plot.bar()

# %%
validate_df['target'].value_counts().plot.bar()

# %%
# get the total amount of data in train and validation set
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# set the minibatch size to 15
batch_size=15

# %%
train_datagen = ImageDataGenerator(
    rotation_range=360,
    rescale=1./255,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "../input/siim-isic-melanoma-classification/jpeg/train/", 
    x_col='image_name',
    y_col='target',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 52185 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "../input/siim-isic-melanoma-classification/jpeg/train/",
    x_col='image_name',
    y_col='target',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 6626 validated image filenames belonging to 2 classes.

# %%
# here we will create a dataframe with one row from the training dataframe for demonstrating
# how the datagenerator works
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "../input/siim-isic-melanoma-classification/jpeg/train/", 
    x_col='image_name',
    y_col='target',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
# we will generate 15 random image from our example data generator and show them using
# matplotlib
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    #on each iteration of the for loop, the generator returns the same amount of random 
    #images as the original dataframe on which the generator was created
    for X_batch, Y_batch in example_generator:
        #get the first image of the generated batch
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
epochs=3 if FAST_RUN else 50

# %%
if(os.path.isfile('saved_model/history.csv') and pd.read_csv('saved_model/history.csv').shape[0]>0):
    iteration_to_be_loaded=pd.read_csv('saved_model/history.csv').shape[0]-1
    model.load_weights("saved_model/model_"+str(iteration_to_be_loaded)+".h5")
    print("saved_model/model_"+str(iteration_to_be_loaded)+".h5"+" loaded!")
# Out:
# saved_model/model_1.h5 loaded!

# %%
# history = model.fit(
#     train_generator, 
#     epochs=epochs,
#     validation_data=validation_generator,
#     validation_steps=total_validate//batch_size,
#     steps_per_epoch=total_train//batch_size,
#     callbacks=callbacks
# )

# %%
test_filenames = os.listdir("../input/siim-isic-melanoma-classification/jpeg/test")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]
nb_samples
# Out:
# 10982

# %%
test_gen = ImageDataGenerator(rescale=1./255)

#remember to not shuffle the test set
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "../input/siim-isic-melanoma-classification/jpeg/test/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 10982 validated image filenames.

# %%
predict = model.predict(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
print(predict.shape)
predict
# Out:
# (10982, 2)
# array([[0.42218912, 0.57781094],
#        [0.7588623 , 0.24113768],
#        [0.9685864 , 0.03141364],
#        ...,
#        [0.4473206 , 0.55267936],
#        [0.254745  , 0.745255  ],
#        [0.08901227, 0.9109877 ]], dtype=float32)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())

# %%
label_map
# Out:
# {0: 'benign', 1: 'malignant'}

# %%
predict[:,1]
# Out:
# array([0.57781094, 0.24113768, 0.03141364, ..., 0.55267936, 0.745255  ,
#        0.9109877 ], dtype=float32)

# %%
test_df['category']=predict[:,1]

# %%
test_df
# Out:
#                filename  category
# 0      ISIC_2951472.jpg  0.577811
# 1      ISIC_0306094.jpg  0.241138
# 2      ISIC_9414809.jpg  0.031414
# 3      ISIC_1964724.jpg  0.797538
# 4      ISIC_0547086.jpg  0.486108
# ...                 ...       ...
# 10977  ISIC_1979700.jpg  0.823205
# 10978  ISIC_8328232.jpg  0.185667
# 10979  ISIC_9937768.jpg  0.552679
# 10980  ISIC_1608729.jpg  0.745255
# 10981  ISIC_3713800.jpg  0.910988
#
# [10982 rows x 2 columns]

# %%
submission_df = test_df.copy()
# image_name,target
submission_df['image_name'] = submission_df['filename'].str.split('.').str[0]
submission_df['target'] = submission_df['category']
submission_df.drop(['filename', 'category'], axis=1, inplace=True)
# I added this line
# submission_df=submission_df.astype({'id': 'int32'})
# submission_df=submission_df.sort_values('id',ascending=True)

submission_df.to_csv('submission.csv', index=False)
