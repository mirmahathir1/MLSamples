# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd 
import keras
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
print(os.listdir("../input"))
# Out:
# ['test1.zip', 'train', '.gitignore', 'train.zip', 'test1', 'dogs-vs-cats.zip', 'sampleSubmission.csv']

# %% [markdown]
# # Define Constants

# %%
# assign FAST_RUN=True to train the model with three epochs
FAST_RUN = False

# input image dimensions
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)

# red, green and blue channels
IMAGE_CHANNELS=3

# %% [markdown]
# # Prepare Traning Data

# %%
# get a list of file names from the train folder
filenames = os.listdir("../input/train/train")
filenames
# Out:
# ['dog.10381.jpg',
#  'cat.508.jpg',
#  'cat.1491.jpg',
#  'cat.10611.jpg',
#  'cat.238.jpg',
#  'cat.10012.jpg',
#  'dog.11894.jpg',
#  'dog.3756.jpg',
#  'cat.12498.jpg',
#  'cat.8718.jpg',
#  'cat.1130.jpg',
#  'dog.9470.jpg',
#  'cat.11346.jpg',
#  'dog.6008.jpg',
#  'dog.10695.jpg',
#  'dog.3105.jpg',
#  'dog.10586.jpg',
#  'cat.7860.jpg',
#  'dog.695.jpg',
#  'dog.2231.jpg',
#  'cat.8937.jpg',
#  'cat.9880.jpg',
#  'dog.2267.jpg',
#  'cat.5551.jpg',
#  'dog.7312.jpg',
#  'dog.9302.jpg',
#  'cat.5905.jpg',
#  'dog.11796.jpg',
#  'cat.10195.jpg',
#  'cat.8683.jpg',
#  'cat.11290.jpg',
#  'cat.5377.jpg',
#  'cat.11504.jpg',
#  'cat.11999.jpg',
#  'dog.11763.jpg',
#  'cat.9385.jpg',
#  'dog.873.jpg',
#  'cat.5031.jpg',
#  'dog.3000.jpg',
#  'dog.7947.jpg',
#  'dog.11836.jpg',
#  'cat.8505.jpg',
#  'dog.2936.jpg',
#  'cat.8777.jpg',
#  'cat.3092.jpg',
#  'dog.6496.jpg',
#  'cat.11005.jpg',
#  'dog.9131.jpg',
#  'cat.3534.jpg',
#  'dog.11071.jpg',
#  'dog.1465.jpg',
#  'dog.1636.jpg',
#  'dog.3747.jpg',
#  'dog.3594.jpg',
#  'dog.6093.jpg',
#  'cat.9063.jpg',
#  'cat.7430.jpg',
#  'cat.10845.jpg',
#  'dog.11881.jpg',
#  'cat.10386.jpg',
#  'dog.10736.jpg',
#  'dog.11089.jpg',
#  'dog.2646.jpg',
#  'cat.8649.jpg',
#  'dog.4107.jpg',
#  'dog.8471.jpg',
#  'dog.5088.jpg',
#  'dog.4019.jpg',
#  'dog.12452.jpg',
#  'cat.3917.jpg',
#  'cat.11311.jpg',
#  'cat.11972.jpg',
#  'cat.6501.jpg',
#  'cat.9520.jpg',
#  'dog.6714.jpg',
#  'cat.6955.jpg',
#  'dog.9394.jpg',
#  'cat.4318.jpg',
#  'dog.1749.jpg',
#  'cat.7822.jpg',
#  'cat.7269.jpg',
#  'dog.12498.jpg',
#  'dog.608.jpg',
#  'dog.12228.jpg',
#  'cat.8241.jpg',
#  'cat.4532.jpg',
#  'dog.7580.jpg',
#  'cat.7773.jpg',
#  'cat.10844.jpg',
#  'cat.5950.jpg',
#  'dog.1689.jpg',
#  'cat.2496.jpg',
#  'dog.6401.jpg',
#  'dog.8354.jpg',
#  'cat.9228.jpg',
#  'cat.7307.jpg',
#  'dog.825.jpg',
#  'cat.11148.jpg',
#  'dog.11279.jpg',
#  'cat.2017.jpg',
#  'dog.7921.jpg',
#  'cat.7932.jpg',
#  'dog.7174.jpg',
#  'dog.2564.jpg',
#  'cat.6642.jpg',
#  'cat.12345.jpg',
#  'dog.8972.jpg',
#  'cat.414.jpg',
#  'dog.9254.jpg',
#  'cat.3847.jpg',
#  'cat.9467.jpg',
#  'dog.762.jpg',
#  'dog.4903.jpg',
#  'cat.7327.jpg',
#  'dog.6459.jpg',
#  'dog.8952.jpg',
#  'dog.389.jpg',
#  'dog.9396.jpg',
#  'dog.11006.jpg',
#  'dog.558.jpg',
#  'cat.11669.jpg',
#  'cat.12439.jpg',
#  'dog.9048.jpg',
#  'dog.12159.jpg',
#  'cat.3718.jpg',
#  'dog.7315.jpg',
#  'cat.9518.jpg',
#  'dog.381.jpg',
#  'cat.10885.jpg',
#  'cat.4510.jpg',
#  'dog.9393.jpg',
#  'cat.5734.jpg',
#  'dog.12311.jpg',
#  'dog.9899.jpg',
#  'dog.270.jpg',
#  'dog.7587.jpg',
#  'dog.4809.jpg',
#  'cat.3972.jpg',
#  'cat.1552.jpg',
#  'dog.10649.jpg',
#  'cat.4795.jpg',
#  'dog.2281.jpg',
#  'dog.2404.jpg',
#  'cat.5710.jpg',
#  'cat.10343.jpg',
#  'dog.6250.jpg',
#  'dog.12192.jpg',
#  'cat.6401.jpg',
#  'dog.583.jpg',
#  'cat.10188.jpg',
#  'cat.11564.jpg',
#  'cat.10733.jpg',
#  'dog.6494.jpg',
#  'dog.5086.jpg',
#  'cat.9363.jpg',
#  'cat.4723.jpg',
#  'cat.1461.jpg',
#  'cat.3266.jpg',
#  'dog.2344.jpg',
#  'dog.12359.jpg',
#  'dog.8512.jpg',
#  'cat.5549.jpg',
#  'dog.764.jpg',
#  'dog.3209.jpg',
#  'dog.5799.jpg',
#  'cat.593.jpg',
#  'cat.2404.jpg',
#  'dog.1920.jpg',
#  'cat.3399.jpg',
#  'cat.2177.jpg',
#  'cat.3711.jpg',
#  'cat.9314.jpg',
#  'cat.9859.jpg',
#  'cat.1052.jpg',
#  'dog.6420.jpg',
#  'dog.9153.jpg',
#  'dog.1738.jpg',
#  'dog.5256.jpg',
#  'cat.4765.jpg',
#  'cat.556.jpg',
#  'cat.1736.jpg',
#  'cat.660.jpg',
#  'cat.10595.jpg',
#  'dog.261.jpg',
#  'cat.1905.jpg',
#  'cat.2731.jpg',
#  'dog.10820.jpg',
#  'cat.3317.jpg',
#  'cat.409.jpg',
#  'dog.8419.jpg',
#  'cat.5501.jpg',
#  'cat.3605.jpg',
#  'dog.10634.jpg',
#  'dog.8968.jpg',
#  'cat.1948.jpg',
#  'dog.12166.jpg',
#  'dog.5213.jpg',
#  'cat.3230.jpg',
#  'dog.3913.jpg',
#  'cat.7222.jpg',
#  'dog.8534.jpg',
#  'dog.10866.jpg',
#  'cat.1556.jpg',
#  'cat.8463.jpg',
#  'dog.5911.jpg',
#  'dog.3584.jpg',
#  'cat.7121.jpg',
#  'cat.5272.jpg',
#  'cat.6356.jpg',
#  'dog.3643.jpg',
#  'dog.6046.jpg',
#  'dog.2632.jpg',
#  'dog.3414.jpg',
#  'cat.12337.jpg',
#  'cat.4786.jpg',
#  'cat.2502.jpg',
#  'cat.10243.jpg',
#  'dog.655.jpg',
#  'dog.8825.jpg',
#  'cat.7152.jpg',
#  'cat.568.jpg',
#  'cat.3453.jpg',
#  'dog.4054.jpg',
#  'dog.4138.jpg',
#  'cat.1760.jpg',
#  'dog.678.jpg',
#  'dog.2802.jpg',
#  'dog.11814.jpg',
#  'cat.4850.jpg',
#  'dog.11197.jpg',
#  'dog.1297.jpg',
#  'dog.3091.jpg',
#  'cat.4159.jpg',
#  'dog.590.jpg',
#  'cat.11796.jpg',
#  'dog.3950.jpg',
#  'cat.529.jpg',
#  'dog.10096.jpg',
#  'cat.1158.jpg',
#  'dog.12185.jpg',
#  'dog.495.jpg',
#  'dog.3275.jpg',
#  'dog.11803.jpg',
#  'cat.11409.jpg',
#  'cat.5122.jpg',
#  'cat.3685.jpg',
#  'dog.654.jpg',
#  'cat.5369.jpg',
#  'cat.9751.jpg',
#  'dog.3100.jpg',
#  'dog.12175.jpg',
#  'dog.3439.jpg',
#  'dog.4373.jpg',
#  'dog.9352.jpg',
#  'cat.726.jpg',
#  'cat.10897.jpg',
#  'cat.5566.jpg',
#  'cat.9948.jpg',
#  'dog.10396.jpg',
#  'dog.10951.jpg',
#  'cat.1020.jpg',
#  'cat.9565.jpg',
#  'dog.9512.jpg',
#  'cat.7627.jpg',
#  'cat.2347.jpg',
#  'cat.8247.jpg',
#  'dog.4325.jpg',
#  'dog.2836.jpg',
#  'cat.7289.jpg',
#  'cat.10051.jpg',
#  'dog.8569.jpg',
#  'cat.8086.jpg',
#  'dog.11131.jpg',
#  'dog.11170.jpg',
#  'dog.9708.jpg',
#  'dog.1718.jpg',
#  'cat.6114.jpg',
#  'dog.2137.jpg',
#  'dog.2332.jpg',
#  'cat.11651.jpg',
#  'cat.793.jpg',
#  'cat.4892.jpg',
#  'dog.6775.jpg',
#  'cat.8690.jpg',
#  'dog.2371.jpg',
#  'cat.3407.jpg',
#  'cat.9765.jpg',
#  'dog.1158.jpg',
#  'cat.9885.jpg',
#  'cat.1619.jpg',
#  'dog.4957.jpg',
#  'dog.740.jpg',
#  'dog.1385.jpg',
#  'dog.1040.jpg',
#  'cat.8873.jpg',
#  'cat.9115.jpg',
#  'cat.4161.jpg',
#  'cat.8904.jpg',
#  'dog.1241.jpg',
#  'dog.7834.jpg',
#  'dog.4700.jpg',
#  'dog.11551.jpg',
#  'dog.10923.jpg',
#  'cat.6116.jpg',
#  'cat.4116.jpg',
#  'cat.1327.jpg',
#  'cat.2599.jpg',
#  'cat.10707.jpg',
#  'dog.6703.jpg',
#  'dog.95.jpg',
#  'dog.8954.jpg',
#  'cat.14.jpg',
#  'cat.773.jpg',
#  'dog.1349.jpg',
#  'cat.6576.jpg',
#  'cat.4273.jpg',
#  'dog.8565.jpg',
#  'cat.3513.jpg',
#  'dog.1706.jpg',
#  'cat.12352.jpg',
#  'cat.11585.jpg',
#  'cat.11280.jpg',
#  'cat.6953.jpg',
#  'cat.1770.jpg',
#  'dog.8281.jpg',
#  'cat.9679.jpg',
#  'cat.5606.jpg',
#  'dog.5113.jpg',
#  'cat.8541.jpg',
#  'cat.2444.jpg',
#  'dog.7879.jpg',
#  'cat.5225.jpg',
#  'cat.1590.jpg',
#  'cat.1682.jpg',
#  'dog.5418.jpg',
#  'dog.3779.jpg',
#  'cat.2232.jpg',
#  'dog.4190.jpg',
#  'dog.3289.jpg',
#  'cat.6341.jpg',
#  'cat.7267.jpg',
#  'dog.2356.jpg',
#  'cat.8398.jpg',
#  'dog.10521.jpg',
#  'cat.320.jpg',
#  'cat.9556.jpg',
#  'dog.4965.jpg',
#  'dog.6861.jpg',
#  'cat.12404.jpg',
#  'cat.651.jpg',
#  'cat.878.jpg',
#  'cat.11078.jpg',
#  'dog.3455.jpg',
#  'cat.9395.jpg',
#  'cat.7064.jpg',
#  'dog.11346.jpg',
#  'dog.1906.jpg',
#  'cat.7921.jpg',
#  'dog.1377.jpg',
#  'cat.5800.jpg',
#  'dog.8897.jpg',
#  'cat.1245.jpg',
#  'dog.4429.jpg',
#  'cat.7510.jpg',
#  'cat.587.jpg',
#  'cat.8548.jpg',
#  'cat.430.jpg',
#  'cat.10403.jpg',
#  'dog.638.jpg',
#  'cat.5658.jpg',
#  'dog.9582.jpg',
#  'cat.1481.jpg',
#  'dog.4090.jpg',
#  'dog.1564.jpg',
#  'cat.6018.jpg',
#  'cat.10762.jpg',
#  'cat.8201.jpg',
#  'dog.10237.jpg',
#  'cat.10038.jpg',
#  'dog.12392.jpg',
#  'cat.7339.jpg',
#  'cat.12284.jpg',
#  'cat.7846.jpg',
#  'dog.337.jpg',
#  'cat.2601.jpg',
#  'dog.4457.jpg',
#  'dog.2593.jpg',
#  'dog.4612.jpg',
#  'cat.6039.jpg',
#  'cat.5568.jpg',
#  'dog.203.jpg',
#  'dog.8223.jpg',
#  'cat.11337.jpg',
#  'cat.7781.jpg',
#  'cat.1338.jpg',
#  'dog.7060.jpg',
#  'dog.6457.jpg',
#  'cat.4322.jpg',
#  'dog.11867.jpg',
#  'cat.335.jpg',
#  'dog.6441.jpg',
#  'cat.9234.jpg',
#  'cat.8701.jpg',
#  'cat.8251.jpg',
#  'dog.8452.jpg',
#  'cat.3892.jpg',
#  'dog.2666.jpg',
#  'dog.6432.jpg',
#  'dog.4888.jpg',
#  'cat.3808.jpg',
#  'cat.5579.jpg',
#  'dog.11604.jpg',
#  'dog.11678.jpg',
#  'dog.10124.jpg',
#  'dog.8030.jpg',
#  'dog.12267.jpg',
#  'dog.10259.jpg',
#  'dog.9355.jpg',
#  'cat.11868.jpg',
#  'dog.7068.jpg',
#  'cat.1326.jpg',
#  'cat.1917.jpg',
#  'dog.6209.jpg',
#  'dog.5195.jpg',
#  'dog.11506.jpg',
#  'cat.2341.jpg',
#  'cat.7062.jpg',
#  'cat.3154.jpg',
#  'cat.9344.jpg',
#  'cat.92.jpg',
#  'cat.2472.jpg',
#  'cat.4235.jpg',
#  'dog.9100.jpg',
#  'dog.8801.jpg',
#  'dog.8855.jpg',
#  'dog.461.jpg',
#  'cat.6640.jpg',
#  'cat.6773.jpg',
#  'cat.6002.jpg',
#  'dog.6060.jpg',
#  'cat.3763.jpg',
#  'dog.5598.jpg',
#  'dog.2314.jpg',
#  'cat.2577.jpg',
#  'dog.1768.jpg',
#  'dog.2884.jpg',
#  'cat.11146.jpg',
#  'cat.11083.jpg',
#  'dog.2566.jpg',
#  'dog.2549.jpg',
#  'cat.5316.jpg',
#  'dog.11866.jpg',
#  'cat.5937.jpg',
#  'dog.10555.jpg',
#  'dog.10777.jpg',
#  'cat.4430.jpg',
#  'cat.11189.jpg',
#  'cat.3786.jpg',
#  'cat.12042.jpg',
#  'cat.2812.jpg',
#  'dog.9961.jpg',
#  'cat.10619.jpg',
#  'dog.7450.jpg',
#  'dog.2333.jpg',
#  'cat.4009.jpg',
#  'cat.11212.jpg',
#  'dog.4585.jpg',
#  'cat.5017.jpg',
#  'cat.3984.jpg',
#  'dog.5426.jpg',
#  'dog.1585.jpg',
#  'cat.11975.jpg',
#  'dog.8912.jpg',
#  'dog.8869.jpg',
#  'dog.11444.jpg',
#  'dog.192.jpg',
#  'dog.1393.jpg',
#  'cat.1690.jpg',
#  'cat.2623.jpg',
#  'dog.5903.jpg',
#  'dog.9798.jpg',
#  'cat.2122.jpg',
#  'dog.7562.jpg',
#  'cat.10575.jpg',
#  'cat.12214.jpg',
#  'cat.7562.jpg',
#  'dog.5384.jpg',
#  'dog.276.jpg',
#  'cat.6106.jpg',
#  'cat.9415.jpg',
#  'dog.1392.jpg',
#  'dog.10668.jpg',
#  'dog.4861.jpg',
#  'dog.5863.jpg',
#  'dog.1864.jpg',
#  'cat.5944.jpg',
#  'cat.1997.jpg',
#  'cat.3919.jpg',
#  'dog.7386.jpg',
#  'cat.2536.jpg',
#  'dog.11349.jpg',
#  'cat.4979.jpg',
#  'cat.11428.jpg',
#  'cat.5474.jpg',
#  'cat.10879.jpg',
#  'dog.8415.jpg',
#  'cat.8879.jpg',
#  'cat.5858.jpg',
#  'dog.765.jpg',
#  'dog.7375.jpg',
#  'cat.6697.jpg',
#  'cat.5856.jpg',
#  'cat.151.jpg',
#  'cat.10591.jpg',
#  'cat.2777.jpg',
#  'cat.10468.jpg',
#  'cat.441.jpg',
#  'cat.9422.jpg',
#  'cat.5530.jpg',
#  'dog.3430.jpg',
#  'dog.6759.jpg',
#  'cat.5886.jpg',
#  'cat.6332.jpg',
#  'dog.1817.jpg',
#  'dog.7466.jpg',
#  'dog.12208.jpg',
#  'dog.6080.jpg',
#  'dog.5804.jpg',
#  'dog.3387.jpg',
#  'dog.5350.jpg',
#  'cat.1468.jpg',
#  'dog.3148.jpg',
#  'cat.1068.jpg',
#  'cat.4251.jpg',
#  'cat.11419.jpg',
#  'dog.1728.jpg',
#  'dog.9952.jpg',
#  'dog.4291.jpg',
#  'dog.7167.jpg',
#  'cat.3436.jpg',
#  'cat.1655.jpg',
#  'cat.5458.jpg',
#  'cat.7941.jpg',
#  'dog.10838.jpg',
#  'cat.9589.jpg',
#  'dog.1606.jpg',
#  'dog.5333.jpg',
#  'dog.1096.jpg',
#  'dog.3154.jpg',
#  'dog.10721.jpg',
#  'dog.3552.jpg',
#  'dog.11225.jpg',
#  'dog.119.jpg',
#  'cat.11457.jpg',
#  'dog.5848.jpg',
#  'cat.1320.jpg',
#  'cat.4173.jpg',
#  'cat.1594.jpg',
#  'dog.3786.jpg',
#  'cat.6591.jpg',
#  'dog.8213.jpg',
#  'dog.3909.jpg',
#  'cat.5681.jpg',
#  'cat.8435.jpg',
#  'dog.7836.jpg',
#  'cat.2970.jpg',
#  'dog.8348.jpg',
#  'cat.10345.jpg',
#  'dog.10143.jpg',
#  'cat.527.jpg',
#  'dog.947.jpg',
#  'dog.9017.jpg',
#  'dog.12444.jpg',
#  'dog.5311.jpg',
#  'dog.5347.jpg',
#  'cat.2039.jpg',
#  'cat.1512.jpg',
#  'cat.6389.jpg',
#  'dog.2023.jpg',
#  'dog.5546.jpg',
#  'dog.12378.jpg',
#  'dog.5947.jpg',
#  'cat.6999.jpg',
#  'dog.11324.jpg',
#  'dog.11514.jpg',
#  'dog.7640.jpg',
#  'dog.4226.jpg',
#  'dog.7092.jpg',
#  'dog.2424.jpg',
#  'cat.9766.jpg',
#  'dog.7300.jpg',
#  'dog.2001.jpg',
#  'dog.1698.jpg',
#  'cat.1329.jpg',
#  'cat.4249.jpg',
#  'dog.8830.jpg',
#  'dog.306.jpg',
#  'dog.10015.jpg',
#  'dog.12482.jpg',
#  'cat.1795.jpg',
#  'dog.1157.jpg',
#  'dog.74.jpg',
#  'cat.2792.jpg',
#  'dog.9199.jpg',
#  'cat.1408.jpg',
#  'cat.2190.jpg',
#  'dog.5372.jpg',
#  'dog.6757.jpg',
#  'cat.7034.jpg',
#  'cat.2214.jpg',
#  'dog.10484.jpg',
#  'cat.4188.jpg',
#  'cat.6834.jpg',
#  'dog.3246.jpg',
#  'cat.7683.jpg',
#  'dog.5985.jpg',
#  'dog.10589.jpg',
#  'dog.935.jpg',
#  'cat.12428.jpg',
#  'dog.3003.jpg',
#  'dog.12163.jpg',
#  'dog.5123.jpg',
#  'cat.11139.jpg',
#  'dog.6554.jpg',
#  'cat.2946.jpg',
#  'cat.4201.jpg',
#  'cat.1264.jpg',
#  'dog.2126.jpg',
#  'cat.7694.jpg',
#  'dog.2563.jpg',
#  'dog.4479.jpg',
#  'dog.3135.jpg',
#  'cat.5181.jpg',
#  'cat.10588.jpg',
#  'cat.6780.jpg',
#  'cat.2098.jpg',
#  'cat.1386.jpg',
#  'dog.115.jpg',
#  'cat.7403.jpg',
#  'dog.6828.jpg',
#  'cat.3488.jpg',
#  'dog.7846.jpg',
#  'cat.1196.jpg',
#  'dog.2144.jpg',
#  'dog.8340.jpg',
#  'dog.9155.jpg',
#  'cat.10665.jpg',
#  'cat.944.jpg',
#  'cat.1394.jpg',
#  'dog.4614.jpg',
#  'dog.8484.jpg',
#  'cat.1538.jpg',
#  'dog.4361.jpg',
#  'cat.3000.jpg',
#  'cat.8097.jpg',
#  'dog.11077.jpg',
#  'dog.11916.jpg',
#  'dog.10042.jpg',
#  'cat.11469.jpg',
#  'dog.7228.jpg',
#  'cat.495.jpg',
#  'dog.9783.jpg',
#  'cat.7167.jpg',
#  'dog.11259.jpg',
#  'dog.3286.jpg',
#  'dog.675.jpg',
#  'dog.5250.jpg',
#  'cat.3610.jpg',
#  'cat.4395.jpg',
#  'cat.6881.jpg',
#  'dog.8403.jpg',
#  'dog.5703.jpg',
#  'dog.2147.jpg',
#  'cat.7960.jpg',
#  'cat.621.jpg',
#  'cat.11715.jpg',
#  'dog.6626.jpg',
#  'dog.9104.jpg',
#  'dog.738.jpg',
#  'cat.948.jpg',
#  'dog.11456.jpg',
#  'dog.985.jpg',
#  'cat.5179.jpg',
#  'dog.3215.jpg',
#  'dog.1208.jpg',
#  'cat.10695.jpg',
#  'cat.4655.jpg',
#  'cat.11376.jpg',
#  'dog.4912.jpg',
#  'cat.4773.jpg',
#  'cat.6611.jpg',
#  'dog.1856.jpg',
#  'cat.8277.jpg',
#  'dog.7322.jpg',
#  'cat.10567.jpg',
#  'cat.1065.jpg',
#  'cat.2595.jpg',
#  'dog.4896.jpg',
#  'cat.7479.jpg',
#  'dog.6550.jpg',
#  'dog.8179.jpg',
#  'dog.417.jpg',
#  'dog.1289.jpg',
#  'cat.2684.jpg',
#  'cat.9093.jpg',
#  'cat.10794.jpg',
#  'dog.2206.jpg',
#  'cat.9433.jpg',
#  'dog.8440.jpg',
#  'cat.6789.jpg',
#  'dog.5024.jpg',
#  'cat.2926.jpg',
#  'dog.9284.jpg',
#  'cat.1601.jpg',
#  'dog.3641.jpg',
#  'cat.2709.jpg',
#  'dog.9484.jpg',
#  'dog.235.jpg',
#  'cat.11709.jpg',
#  'dog.530.jpg',
#  'cat.7558.jpg',
#  'dog.1558.jpg',
#  'cat.10836.jpg',
#  'dog.5176.jpg',
#  'dog.6419.jpg',
#  'dog.5028.jpg',
#  'cat.6010.jpg',
#  'cat.10352.jpg',
#  'cat.6917.jpg',
#  'dog.8758.jpg',
#  'cat.8111.jpg',
#  'dog.4632.jpg',
#  'cat.3817.jpg',
#  'cat.2446.jpg',
#  'dog.12459.jpg',
#  'dog.5817.jpg',
#  'dog.213.jpg',
#  'dog.9440.jpg',
#  'dog.10750.jpg',
#  'cat.9564.jpg',
#  'cat.846.jpg',
#  'cat.860.jpg',
#  'cat.6786.jpg',
#  'cat.4492.jpg',
#  'cat.7209.jpg',
#  'dog.407.jpg',
#  'dog.5624.jpg',
#  'cat.8005.jpg',
#  'dog.3908.jpg',
#  'dog.6959.jpg',
#  'dog.7486.jpg',
#  'dog.9781.jpg',
#  'dog.5090.jpg',
#  'cat.58.jpg',
#  'cat.9198.jpg',
#  'cat.12450.jpg',
#  'dog.2454.jpg',
#  'dog.3754.jpg',
#  'cat.9142.jpg',
#  'cat.6411.jpg',
#  'dog.3878.jpg',
#  'cat.6322.jpg',
#  'cat.12077.jpg',
#  'dog.2290.jpg',
#  'cat.11178.jpg',
#  'cat.11682.jpg',
#  'dog.6150.jpg',
#  'cat.10757.jpg',
#  'dog.7399.jpg',
#  'dog.3462.jpg',
#  'cat.4238.jpg',
#  'cat.1607.jpg',
#  'dog.6411.jpg',
#  'cat.1892.jpg',
#  'cat.3493.jpg',
#  'dog.9735.jpg',
#  'cat.7670.jpg',
#  'cat.2351.jpg',
#  'dog.4930.jpg',
#  'cat.9828.jpg',
#  'cat.8439.jpg',
#  'cat.7038.jpg',
#  'cat.1662.jpg',
#  'cat.1600.jpg',
#  'dog.10052.jpg',
#  'dog.10743.jpg',
#  'dog.8612.jpg',
#  'dog.2004.jpg',
#  'cat.1005.jpg',
#  'dog.11640.jpg',
#  'dog.6776.jpg',
#  'cat.6102.jpg',
#  'dog.5323.jpg',
#  'cat.2129.jpg',
#  'cat.916.jpg',
#  'dog.1868.jpg',
#  'cat.2436.jpg',
#  'dog.9994.jpg',
#  'dog.11710.jpg',
#  'dog.788.jpg',
#  'cat.6433.jpg',
#  'cat.1528.jpg',
#  'dog.1195.jpg',
#  'dog.10377.jpg',
#  'cat.2726.jpg',
#  'cat.10330.jpg',
#  'dog.5652.jpg',
#  'cat.3098.jpg',
#  'cat.10598.jpg',
#  'cat.8368.jpg',
#  'dog.10789.jpg',
#  'cat.3306.jpg',
#  'cat.3412.jpg',
#  'cat.5021.jpg',
#  'cat.11932.jpg',
#  'dog.4021.jpg',
#  'dog.2686.jpg',
#  'dog.2143.jpg',
#  'cat.12489.jpg',
#  'dog.9266.jpg',
#  'cat.3669.jpg',
#  'dog.10742.jpg',
#  'cat.4366.jpg',
#  'dog.1522.jpg',
#  'dog.6265.jpg',
#  'cat.8196.jpg',
#  'cat.2831.jpg',
#  'dog.2070.jpg',
#  'cat.11522.jpg',
#  'dog.2215.jpg',
#  'cat.3181.jpg',
#  'dog.5589.jpg',
#  'dog.4587.jpg',
#  'dog.8913.jpg',
#  'cat.11165.jpg',
#  'dog.1186.jpg',
#  'dog.9125.jpg',
#  'dog.11325.jpg',
#  'cat.5999.jpg',
#  'dog.5427.jpg',
#  'cat.9936.jpg',
#  'cat.4833.jpg',
#  'cat.2359.jpg',
#  'dog.8989.jpg',
#  'cat.6749.jpg',
#  'dog.7704.jpg',
#  'dog.5411.jpg',
#  'cat.10795.jpg',
#  'cat.9777.jpg',
#  'dog.5095.jpg',
#  'cat.12104.jpg',
#  'cat.2618.jpg',
#  'cat.1898.jpg',
#  'dog.2240.jpg',
#  'dog.3577.jpg',
#  'dog.5014.jpg',
#  'dog.6073.jpg',
#  'dog.4117.jpg',
#  'dog.4997.jpg',
#  'cat.7685.jpg',
#  'cat.9001.jpg',
#  'cat.10982.jpg',
#  'cat.11942.jpg',
#  'dog.4583.jpg',
#  'dog.11026.jpg',
#  'cat.9029.jpg',
#  'dog.8789.jpg',
#  'dog.4760.jpg',
#  'cat.5609.jpg',
#  'cat.11475.jpg',
#  'dog.4470.jpg',
#  'dog.10510.jpg',
#  'cat.10263.jpg',
#  'cat.5747.jpg',
#  'cat.10049.jpg',
#  'cat.9959.jpg',
#  'dog.1411.jpg',
#  'cat.1424.jpg',
#  'cat.7949.jpg',
#  'dog.11620.jpg',
#  'cat.873.jpg',
#  'dog.11936.jpg',
#  'cat.11423.jpg',
#  'cat.10477.jpg',
#  'dog.674.jpg',
#  'dog.257.jpg',
#  'dog.2117.jpg',
#  'dog.17.jpg',
#  'cat.8665.jpg',
#  'cat.3483.jpg',
#  'cat.7386.jpg',
#  'cat.5412.jpg',
#  'cat.1946.jpg',
#  'cat.9346.jpg',
#  'cat.2357.jpg',
#  'dog.8868.jpg',
#  'cat.11100.jpg',
#  'dog.4756.jpg',
#  'cat.12148.jpg',
#  'cat.1963.jpg',
#  'dog.5680.jpg',
#  'cat.6285.jpg',
#  'cat.3239.jpg',
#  'cat.9521.jpg',
#  'cat.5924.jpg',
#  'cat.11525.jpg',
#  'dog.271.jpg',
#  'cat.12246.jpg',
#  'dog.10726.jpg',
#  'cat.7640.jpg',
#  'dog.4617.jpg',
#  'dog.10754.jpg',
#  'dog.8183.jpg',
#  'dog.7078.jpg',
#  'dog.6469.jpg',
#  'dog.11715.jpg',
#  'cat.7735.jpg',
#  'cat.643.jpg',
#  'cat.4716.jpg',
#  'dog.3681.jpg',
#  'dog.4093.jpg',
#  'dog.5047.jpg',
#  'cat.1242.jpg',
#  'dog.380.jpg',
#  'cat.9988.jpg',
#  'dog.8999.jpg',
#  'dog.5136.jpg',
#  'dog.8574.jpg',
#  'dog.10142.jpg',
#  'dog.3853.jpg',
#  'cat.11486.jpg',
#  'cat.1406.jpg',
#  'cat.6728.jpg',
#  'dog.4946.jpg',
#  'cat.7692.jpg',
#  'cat.12166.jpg',
#  'dog.1143.jpg',
#  'cat.8833.jpg',
#  'dog.4711.jpg',
#  'dog.5368.jpg',
#  'cat.6676.jpg',
#  'cat.10612.jpg',
#  'cat.7852.jpg',
#  'cat.790.jpg',
#  'cat.2244.jpg',
#  'dog.9684.jpg',
#  'cat.3714.jpg',
#  'cat.7851.jpg',
#  'cat.4135.jpg',
#  'dog.9829.jpg',
#  'dog.3743.jpg',
#  'dog.5865.jpg',
#  'cat.122.jpg',
#  'dog.7708.jpg',
#  'dog.4258.jpg',
#  'cat.2078.jpg',
#  'cat.8234.jpg',
#  'dog.7294.jpg',
#  'dog.11168.jpg',
#  'cat.5545.jpg',
#  'cat.6623.jpg',
#  'cat.9531.jpg',
#  'cat.8949.jpg',
#  'cat.4347.jpg',
#  'cat.2132.jpg',
#  'dog.10730.jpg',
#  'dog.4256.jpg',
#  'dog.11316.jpg',
#  'cat.4265.jpg',
#  'dog.6669.jpg',
#  'cat.2225.jpg',
#  'dog.804.jpg',
#  'dog.2877.jpg',
#  'dog.3051.jpg',
#  'cat.2119.jpg',
#  'dog.651.jpg',
#  'dog.3381.jpg',
#  'dog.8777.jpg',
#  'cat.9591.jpg',
#  'dog.4934.jpg',
#  'dog.9935.jpg',
#  'cat.1787.jpg',
#  'dog.5061.jpg',
#  'dog.8659.jpg',
#  'dog.11985.jpg',
#  'cat.2585.jpg',
#  'cat.1691.jpg',
#  'cat.6969.jpg',
#  'dog.7603.jpg',
#  'cat.7648.jpg',
#  'dog.1875.jpg',
#  'cat.1266.jpg',
#  'cat.8576.jpg',
#  'dog.10605.jpg',
#  'cat.9129.jpg',
#  'dog.10093.jpg',
#  'dog.8019.jpg',
#  'dog.3410.jpg',
#  'dog.410.jpg',
#  'cat.4383.jpg',
#  ...]

# %%
# an empty list which will contain all the labels of the train images.
# for example: for cat.8937.jpg- 0 will be appended to the list. for dog.695.jpg- 1 will be 
# appended to the list
categories = []
for filename in filenames:
    
    # split the filename using delimiter '.'.
    # for example, 'cat.8937.jpg' will be splitted into 'cat','8937','jpg'. we will take the
    # first string 'cat' as the category of that image
    category = filename.split('.')[0]
    
    # We will label all the images with dog photos as 1's and cat photos as 0's
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

# we will create a dataframe which will contain the filenames and the labels of our train set
df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#         filename  category
# 0  dog.10381.jpg         1
# 1    cat.508.jpg         0
# 2   cat.1491.jpg         0
# 3  cat.10611.jpg         0
# 4    cat.238.jpg         0

# %%
df.tail()
# Out:
#             filename  category
# 24995  dog.10628.jpg         1
# 24996   cat.9868.jpg         0
# 24997   dog.1441.jpg         1
# 24998  dog.10308.jpg         1
# 24999  dog.11479.jpg         1

# %% [markdown]
# ### See Total In count

# %%
# create a barplot showing the amount of cat and dog pictures
df['category'].value_counts().plot.bar()

# %% [markdown]
# From our data we have 12000 cats and 12000 dogs

# %% [markdown]
# # See sample image

# %%
# randomly choose an image for display
sample = random.choice(filenames)
image = load_img("../input/train/train/"+sample)
plt.imshow(image)

# %% [markdown]
# # Build Model
#
# <img src="https://i.imgur.com/ebkMGGu.jpg" width="100%"/>

# %% [markdown]
# * **Input Layer**: It represent input image data. It will reshape image into single diminsion array. Example your image is 64x64 = 4096, it will convert to (4096,1) array.
# * **Conv Layer**: This layer will extract features from image.
# * **Pooling Layer**: This layerreduce the spatial volume of input image after convolution.
# * **Fully Connected Layer**: It connect the network from a layer to another layer
# * **Output Layer**: It is the predicted values layer.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

# layer 1
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#layer 2
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#layer 3
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#fully connected layer
model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

# %% [markdown]
# ##### my understanding on the last layer:
# we will use a softmax activation on the last layer when we have categorical dependent variable. otherwise, we will use a normal dense layer

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 61, 61, 64)        18496
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 61, 61, 64)        256
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %% [markdown]
# ##### my understanding on loss function:
# we will use categorical cross entropy for categorical output. we will use mean squared error for non-categorical output.
# ##### my understanding on optimizer:
# we will use Root Mean Square Propogation for categorical output. For non-categorical output, we will use adam optimization.
# ##### my understanding on performance metrics:
# we will use accuracy for categorical output. We will use mean absolute error for non-categorical output

# %% [markdown]
# # Callbacks

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# **Early Stop**
#
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# **Learning Rate Reduction**
#
# We will reduce the learning rate when then validation accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
import json
import os

class CustomSaver(keras.callbacks.Callback):
    def __init__(self):
        super().__init__(self)
        if(~os.path.isfile('saved_model/history.csv')):
            history_df=pd.DataFrame(columns=['loss','val_loss', 'accuracy','val_accuracy'])
            history_df.to_csv('saved_model/history.csv')
        self.history_df = pd.read_csv('saved_model/history.csv')
        
    def on_epoch_end(self, epoch, logs={}):
        print("Epoch:",epoch)
#         self.model.save("saved_model/model")
        print("Loss:",logs["loss"],"Val_loss:",logs["val_loss"],"Accuracy:",logs["accuracy"],"Val_accuracy:",logs["val_accuracy"])
        self.model.save_weights("saved_model/model.h5")
        self.history_df.append({'loss':logs["loss"],
                                'val_loss':logs['val_loss'],
                                'accuracy':logs['accuracy'],
                                'val_accuracy':logs['val_accuracy']})
        self.history_df.to_csv('saved_model/history.csv')
         
saver = CustomSaver()

# %%
logs={'loss':1,'val_loss':2,'accuracy':3,'val_accuracy':4}

if(~os.path.isfile('saved_model/history.csv')):
    history_df=pd.DataFrame(columns=['loss','val_loss', 'accuracy','val_accuracy'])
    history_df.to_csv('saved_model/history.csv')
history_df = pd.read_csv('saved_model/history.csv')
history_df.append({'loss':logs["loss"],
                   'val_loss':logs['val_loss'],
                   'accuracy':logs['accuracy'],
                   'val_accuracy':logs['val_accuracy']},ignore_index = True)
history_df.to_csv('saved_model/history.csv')

# %%
callbacks = [earlystop, learning_rate_reduction, saver]

# %% [markdown]
# # Prepare data

# %% [markdown]
# Because we will use image genaretor `with class_mode="categorical"`. We need to convert column category into string. Then imagenerator will convert it one-hot encoding which is good for our classification.
#
# So we will convert 1 to dog and 0 to cat

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

# %%
# do a train-validation split on the whole set.
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)

# drop the indexes of train and validation dataframe
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
# see the amount of cat and dog photos in the train dataframe
train_df['category'].value_counts().plot.bar()

# %%
# see the amount of cat and dog photos in the train dataframe
validate_df['category'].value_counts().plot.bar()

# %%
# get the total amount of data in train and validation set
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# set the minibatch size to 15
batch_size=15

# %% [markdown]
# # Traning Generator

# %%
# ImageDataGenerator?

# %%
#  Generate batches of tensor image data with real-time data augmentation.
#  The data will be looped over (in batches)

# Degree range for random rotations is 15
# rescaling factor is 1/255, meaning that the image pixel values will be multiplied by 1/255
# Shear angle in counter-clockwise direction in degrees is 0.1
# Range for random zoom is 0.2
# Randomly flip inputs horizontally
# width_shift_range 0.1 fraction of total width
# height_shift_range 0.1 fraction of total height
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %%
# train_datagen.flow_from_dataframe?

# %%
# Takes the dataframe and the path to a directory
#  and generates batches of augmented/normalized data.

# target_size: The dimensions to which all images found will be resized
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "../input/train/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Validation Generator

# %%
# we will definitely not need to zoom, shear, or any kind of bullshit to increase validation
# set but we will divide the pixel values by 255

validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "../input/train/train/",
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %% [markdown]
# # See how our generator work

# %%
# here we will create a dataframe with one row from the training dataframe for demonstrating
# how the datagenerator works
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "../input/train/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
# we will generate 15 random image from our example data generator and show them using
# matplotlib
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    #on each iteration of the for loop, the generator returns the same amount of random 
    #images as the original dataframe on which the generator was created
    for X_batch, Y_batch in example_generator:
        #get the first image of the generated batch
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# Seem to be nice

# %% [markdown]
# # Fit Model

# %% [markdown]
# Uncomment the following cell to run training

# %%
model.load_weights("saved_model/model.h5")

# %%
epochs=3 if FAST_RUN else 50
history = model.fit(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 1333/1333 [==============================] - 182s 136ms/step - loss: 0.4375 - accuracy: 0.8049 - val_loss: 0.4084 - val_accuracy: 0.8130
# Epoch: 0
# Loss: 0.43764493815938266 Val_loss: 0.40843212604522705 Accuracy: 0.8048536 Val_accuracy: 0.8130130171775818
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-7fbc4581965a> in <module>
#       6     validation_steps=total_validate//batch_size,
#       7     steps_per_epoch=total_train//batch_size,
# ----> 8     callbacks=callbacks
#       9 )
#
# ~/miniconda3/envs/machine/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1145                 use_multiprocessing=use_multiprocessing,
#    1146                 shuffle=shuffle,
# -> 1147                 initial_epoch=initial_epoch)
#    1148
#    1149         # Case 2: Symbolic tensors or Numpy array-like.
#
# ~/miniconda3/envs/machine/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/miniconda3/envs/machine/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~/miniconda3/envs/machine/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     258                     break
#     259
# --> 260             callbacks.on_epoch_end(epoch, epoch_logs)
#     261             epoch += 1
#     262             if callbacks.model.stop_training:
#
# ~/miniconda3/envs/machine/lib/python3.6/site-packages/keras/callbacks/callbacks.py in on_epoch_end(self, epoch, logs)
#     150         logs = logs or {}
#     151         for callback in self.callbacks:
# --> 152             callback.on_epoch_end(epoch, logs)
#     153
#     154     def on_train_batch_begin(self, batch, logs=None):
#
# <ipython-input-96-8b1485277d97> in on_epoch_end(self, epoch, logs)
#      19         print("Loss:",logs["loss"],"Val_loss:",logs["val_loss"],"Accuracy:",logs["accuracy"],"Val_accuracy:",logs["val_accuracy"])
#      20         self.model.save_weights("saved_model/model.h5")
# ---> 21         self.append_new_line("saved_model/history.csv",""+str(logs["loss"])+","+str(logs["val_loss"])+","+str(logs["accuracy"])+","+str(logs["val_accuracy"]))
#      22
#      23 saver = CustomSaver()
#
# TypeError: append_new_line() takes 2 positional arguments but 3 were given

# %%
assert(False)

# %% [markdown]
# # Save Model

# %%
# model.save_weights("saved_model/model.h5")

# import pickle
# with open('saved_model/history.pickle', 'wb') as f:
#     pickle.dump(history, f)

# %%
model.load_weights("saved_model/model.h5")

import pickle
with open('saved_model/history.pickle','rb') as f:
    history = pickle.load(f)

# %% [markdown]
# # Visualize Training

# %%
# create a figure with two subplots in 2 rows and one column
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))

#draw losses on the first subplot
# plot the training loss
ax1.plot(history.history['loss'], color='b', label="Training loss")
#plot the validation loss
ax1.plot(history.history['val_loss'], color='r', label="validation loss")

ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

#draw accuracy on the second subplot
# training accuracy
ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
# validation accuracy
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")

ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Prepare Testing Data

# %%
test_filenames = os.listdir("../input/test1/test1")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %% [markdown]
# # Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale=1./255)

#remember to not shuffle the test set
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "../input/test1/test1/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# # Predict

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
predict

# %% [markdown]
# For categoral classication the prediction will come with probability of each category. So we will pick the category that have the highest probability with numpy average max

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
test_df['category']

# %% [markdown]
# We will convert the predict category back into our generator classes by using `train_generator.class_indices`. It is the classes that image generator map while converting data into computer vision

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
test_df['category']

# %% [markdown]
# From our prepare data part. We map data with `{1: 'dog', 0: 'cat'}`. Now we will map the result back to dog is 1 and cat is 0

# %%
test_df['category'] = test_df['category'].replace({ 'dog': 1, 'cat': 0 })

# %% [markdown]
# ### Visualize Result

# %%
test_df['category'].value_counts().plot.bar()

# %% [markdown]
# ### See predicted result with images

# %%
sample_test = test_df.head(18)
sample_test.head(18)

# %%
plt.figure(figsize=(12, 24))

# iterrows() will return index and each row of a dataframe
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img("../input/test1/test1/"+filename, target_size=IMAGE_SIZE)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')' )
plt.tight_layout()
plt.show()

# %% [markdown]
# # Submission

# %%
submission_df = test_df.copy()
submission_df['id'] = submission_df['filename'].str.split('.').str[0]
submission_df['label'] = submission_df['category']
submission_df.drop(['filename', 'category'], axis=1, inplace=True)
# I added this line
submission_df=submission_df.astype({'id': 'int32'})
submission_df=submission_df.sort_values('id',ascending=True)

submission_df.to_csv('submission.csv', index=False)
