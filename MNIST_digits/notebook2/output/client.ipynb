# %%
# %reset -f
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import cv2
import tensorflow as tf
from digitLib import DigitCanvas, DigitModel

# %%
digitModel = DigitModel()

# %%
digitCanvas = DigitCanvas()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
image = digitCanvas.getDrawing()

# %%
digitModel.predict(image)
# Out:
# 4
